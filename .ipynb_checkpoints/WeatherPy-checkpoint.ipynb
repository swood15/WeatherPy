# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import openweathermapy.core as owm
import matplotlib.pyplot as plt
from pprint import pprint
import pandas as pd
import numpy as np
import requests
import json
import time

# Import API key
from config import owm_key, gmap_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output = "output/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
coord = []
cities = []
countries = []

# Create a set of random lat and lng combinations
lat = np.random.uniform(low=-90.000, high=90.000, size=1000000)
lng = np.random.uniform(low=-180.000, high=180.000, size=1000000)
coord = zip(lat, lng)

# Identify nearest city for each lat, lng combination
for loc in coord:
    city = citipy.nearest_city(loc[0], loc[1])
    
    # If the city is unique, then add it to a our cities list
    if city.city_name.title() not in cities:
        cities.append(city.city_name.title())
        countries.append(city.country_code.upper())
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 80

# %%
# Create dataframe
df = pd.DataFrame({
    'City': cities,
    'Country': countries   
})

df['Latitude'] = ""
df['Longitude'] = ""
df['Elevation'] = ""
df['Max Temp'] = ""
df['Humidity'] =  ""
df['Wind Speed'] = ""
df['Cloudiness'] = ""
df['Date'] = ""

df.head()
# Out:
#            City Country Latitude Longitude Elevation Max Temp Humidity  \
# 0  Kudahuvadhoo      MV
# 1     Tuatapere      NZ
# 2   Nizhneyansk      RU
# 3         Tyrma      RU
# 4        Kodiak      US
#
#   Wind Speed Cloudiness Date
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
settings = {"units": "imperial", "appid": owm_key}
units = 'imperial'

print(f'ALL YOUR DATA ARE BELONG TO US.')
print('--------------------------------------')

errCount = 0
for index, row in df.iterrows():
    print(f'Processing record {index} of {len(cities)-1} | {row["City"]}, {row["Country"]}')
    city = row['City']
    country = row['Country']
    url = f'http://api.openweathermap.org/data/2.5/weather?&appid={owm_key}&q={city},{country}&units={units}'
    data = requests.get(url).json()
    try:
        df.loc[index, 'Latitude'] = data['coord']['lat']
        df.loc[index, 'Longitude'] = data['coord']['lon']
        df.loc[index, 'Max Temp'] = data['main']['temp_max']
        df.loc[index, 'Humidity'] = data['main']['humidity']
        df.loc[index, 'Wind Speed'] = data['wind']['speed']
        df.loc[index, 'Cloudiness'] = data['clouds']['all']
        df.loc[index, 'Date'] = data['dt']
    except (KeyError, IndexError):
        print(f'   Error due to crappy weather data, dropping record {index}.')
        df = df.drop(index=index)
        errCount += 1
    
print('--------------------------------------')         
print(f'WEATHER DATA RETRIEVAL COMPLETE WITH {errCount} ERRORS.')
print('--------------------------------------')

df = df.reset_index(drop=True)
df.to_csv('Output/Weather_Data.csv')
# Out:
# ALL YOUR DATA ARE BELONG TO US.
# --------------------------------------
# Processing record 0 of 79 | Kudahuvadhoo, MV
# Processing record 1 of 79 | Tuatapere, NZ
# Processing record 2 of 79 | Nizhneyansk, RU
#    Error due to crappy weather data, dropping record 2.
# Processing record 3 of 79 | Tyrma, RU
# Processing record 4 of 79 | Kodiak, US
# Processing record 5 of 79 | Namatanai, PG
# Processing record 6 of 79 | Qaanaaq, GL
# Processing record 7 of 79 | Lavrentiya, RU
# Processing record 8 of 79 | Provideniya, RU
# Processing record 9 of 79 | Cheremshan, RU
# Processing record 10 of 79 | Sentyabrskiy, RU
#    Error due to crappy weather data, dropping record 10.
# Processing record 11 of 79 | Hilo, US
# Processing record 12 of 79 | Owando, CG
# Processing record 13 of 79 | Marcona, PE
#    Error due to crappy weather data, dropping record 13.
# Processing record 14 of 79 | Florida, UY
# Processing record 15 of 79 | Upernavik, GL
# Processing record 16 of 79 | Tasiilaq, GL
# Processing record 17 of 79 | Ginda, ER
#    Error due to crappy weather data, dropping record 17.
# Processing record 18 of 79 | San Cristobal, EC
# Processing record 19 of 79 | Ribeira Grande, PT
# Processing record 20 of 79 | Rikitea, PF
# Processing record 21 of 79 | Sumbawa, ID
#    Error due to crappy weather data, dropping record 21.
# Processing record 22 of 79 | Umzimvubu, ZA
#    Error due to crappy weather data, dropping record 22.
# Processing record 23 of 79 | Novobiryusinskiy, RU
# Processing record 24 of 79 | Khatanga, RU
# Processing record 25 of 79 | Severo-Kurilsk, RU
# Processing record 26 of 79 | Arraial Do Cabo, BR
# Processing record 27 of 79 | Trapani, IT
# Processing record 28 of 79 | Shizunai, JP
# Processing record 29 of 79 | Haines Junction, CA
# Processing record 30 of 79 | Hobart, AU
# Processing record 31 of 79 | Pascagoula, US
# Processing record 32 of 79 | Poum, NC
# Processing record 33 of 79 | Nikolayevsk-Na-Amure, RU
# Processing record 34 of 79 | Mataura, PF
#    Error due to crappy weather data, dropping record 34.
# Processing record 35 of 79 | Atuona, PF
# Processing record 36 of 79 | Torbay, CA
# Processing record 37 of 79 | Ushuaia, AR
# Processing record 38 of 79 | Roald, NO
# Processing record 39 of 79 | Zabid, YE
# Processing record 40 of 79 | Busselton, AU
# Processing record 41 of 79 | Alugan, PH
# Processing record 42 of 79 | New Norfolk, AU
# Processing record 43 of 79 | Hermanus, ZA
# Processing record 44 of 79 | Chamalieres, FR
# Processing record 45 of 79 | Albany, AU
# Processing record 46 of 79 | Condega, NI
# Processing record 47 of 79 | Bobcaygeon, CA
# Processing record 48 of 79 | Guerrero Negro, MX
# Processing record 49 of 79 | Huarmey, PE
# Processing record 50 of 79 | Grand Centre, CA
#    Error due to crappy weather data, dropping record 50.
# Processing record 51 of 79 | Rawson, AR
# Processing record 52 of 79 | El Fuerte, MX
# Processing record 53 of 79 | Klaksvik, FO
# Processing record 54 of 79 | Iqaluit, CA
# Processing record 55 of 79 | San Rafael, AR
# Processing record 56 of 79 | Plymouth, GB
# Processing record 57 of 79 | Hithadhoo, MV
# Processing record 58 of 79 | Constitucion, CL
# Processing record 59 of 79 | Estelle, US
# Processing record 60 of 79 | Kapaa, US
# Processing record 61 of 79 | Bluff, NZ
# Processing record 62 of 79 | Haibowan, CN
#    Error due to crappy weather data, dropping record 62.
# Processing record 63 of 79 | Tsihombe, MG
#    Error due to crappy weather data, dropping record 63.
# Processing record 64 of 79 | Prince Rupert, CA
# Processing record 65 of 79 | Castro, CL
# Processing record 66 of 79 | Meghradzor, AM
# Processing record 67 of 79 | Butaritari, KI
# Processing record 68 of 79 | Cape Town, ZA
# Processing record 69 of 79 | Grindavik, IS
# Processing record 70 of 79 | Kahului, US
# Processing record 71 of 79 | Kamenskoye, RU
#    Error due to crappy weather data, dropping record 71.
# Processing record 72 of 79 | Port Elizabeth, ZA
# Processing record 73 of 79 | Rivne, UA
# Processing record 74 of 79 | Sataua, WS
#    Error due to crappy weather data, dropping record 74.
# Processing record 75 of 79 | Punta Arenas, CL
# Processing record 76 of 79 | Ponta Do Sol, PT
# Processing record 77 of 79 | Gamba, GA
# Processing record 78 of 79 | Grand Gaube, MU
# Processing record 79 of 79 | Thompson, CA
# --------------------------------------
# WEATHER DATA RETRIEVAL COMPLETE WITH 12 ERRORS.
# --------------------------------------

# %%
print(f'MOAR DATA!')
print('--------------------------------------')

errCount = 0
for index, row in df.iterrows():
    if row['Elevation'] == "":
        print(f'Processing record {index} of {len(df)-1} | {row["City"]}, {row["Country"]}')
        lat = row['Latitude']
        lng = row['Longitude']
        coord = f'{lat}, {lng}'
        params = {
            "locations": coord,
            "key": gmap_key
        }
        url = "https://maps.googleapis.com/maps/api/elevation/json"
        data = requests.get(url, params=params).json()
        try:
            df.loc[index, 'Elevation'] = data['results'][0]['elevation']
        except (KeyError, IndexError):
            print(f'   Error due to crappy elevation data, skipping record {index}.')
            df = df.drop(index=index)
            errCount += 1

print('--------------------------------------')         
print(f'ELEVATION DATA RETRIEVAL COMPLETE WITH {errCount} ERRORS.')
print('--------------------------------------')

df = df.reset_index(drop=True)
df.to_csv('Output/Elevation_Data.csv')
df.head()
# Out:
# MOAR DATA!
# --------------------------------------
# Processing record 0 of 67 | Kudahuvadhoo, MV
# Processing record 1 of 67 | Tuatapere, NZ
# Processing record 2 of 67 | Tyrma, RU
# Processing record 3 of 67 | Kodiak, US
# Processing record 4 of 67 | Namatanai, PG
# Processing record 5 of 67 | Qaanaaq, GL
# Processing record 6 of 67 | Lavrentiya, RU
# Processing record 7 of 67 | Provideniya, RU
# Processing record 8 of 67 | Cheremshan, RU
# Processing record 9 of 67 | Hilo, US
# Processing record 10 of 67 | Owando, CG
# Processing record 11 of 67 | Florida, UY
# Processing record 12 of 67 | Upernavik, GL
# Processing record 13 of 67 | Tasiilaq, GL
# Processing record 14 of 67 | San Cristobal, EC
# Processing record 15 of 67 | Ribeira Grande, PT
# Processing record 16 of 67 | Rikitea, PF
# Processing record 17 of 67 | Novobiryusinskiy, RU
# Processing record 18 of 67 | Khatanga, RU
# Processing record 19 of 67 | Severo-Kurilsk, RU
# Processing record 20 of 67 | Arraial Do Cabo, BR
# Processing record 21 of 67 | Trapani, IT
# Processing record 22 of 67 | Shizunai, JP
# Processing record 23 of 67 | Haines Junction, CA
# Processing record 24 of 67 | Hobart, AU
# Processing record 25 of 67 | Pascagoula, US
# Processing record 26 of 67 | Poum, NC
# Processing record 27 of 67 | Nikolayevsk-Na-Amure, RU
# Processing record 28 of 67 | Atuona, PF
# Processing record 29 of 67 | Torbay, CA
# Processing record 30 of 67 | Ushuaia, AR
# Processing record 31 of 67 | Roald, NO
# Processing record 32 of 67 | Zabid, YE
# Processing record 33 of 67 | Busselton, AU
# Processing record 34 of 67 | Alugan, PH
# Processing record 35 of 67 | New Norfolk, AU
# Processing record 36 of 67 | Hermanus, ZA
# Processing record 37 of 67 | Chamalieres, FR
# Processing record 38 of 67 | Albany, AU
# Processing record 39 of 67 | Condega, NI
# Processing record 40 of 67 | Bobcaygeon, CA
# Processing record 41 of 67 | Guerrero Negro, MX
# Processing record 42 of 67 | Huarmey, PE
# Processing record 43 of 67 | Rawson, AR
# Processing record 44 of 67 | El Fuerte, MX
# Processing record 45 of 67 | Klaksvik, FO
# Processing record 46 of 67 | Iqaluit, CA
# Processing record 47 of 67 | San Rafael, AR
# Processing record 48 of 67 | Plymouth, GB
# Processing record 49 of 67 | Hithadhoo, MV
# Processing record 50 of 67 | Constitucion, CL
# Processing record 51 of 67 | Estelle, US
# Processing record 52 of 67 | Kapaa, US
# Processing record 53 of 67 | Bluff, NZ
# Processing record 54 of 67 | Prince Rupert, CA
# Processing record 55 of 67 | Castro, CL
# Processing record 56 of 67 | Meghradzor, AM
# Processing record 57 of 67 | Butaritari, KI
# Processing record 58 of 67 | Cape Town, ZA
# Processing record 59 of 67 | Grindavik, IS
# Processing record 60 of 67 | Kahului, US
# Processing record 61 of 67 | Port Elizabeth, ZA
# Processing record 62 of 67 | Rivne, UA
# Processing record 63 of 67 | Punta Arenas, CL
# Processing record 64 of 67 | Ponta Do Sol, PT
# Processing record 65 of 67 | Gamba, GA
# Processing record 66 of 67 | Grand Gaube, MU
# Processing record 67 of 67 | Thompson, CA
# --------------------------------------
# ELEVATION DATA RETRIEVAL COMPLETE WITH 0 ERRORS.
# --------------------------------------
#            City Country Latitude Longitude Elevation Max Temp Humidity  \
# 0  Kudahuvadhoo      MV     2.67     72.89   3.74438    79.53      100
# 1     Tuatapere      NZ   -46.13    167.69        25    45.96      100
# 2         Tyrma      RU    50.04    132.17   331.092    57.57       53
# 3        Kodiak      US    39.95    -94.76   292.709    53.06       77
# 4     Namatanai      PG    -3.66    152.44         0    84.84       94
#
#   Wind Speed Cloudiness        Date
# 0      17.38         88  1538015148
# 1       7.31         92  1538015148
# 2       2.62          0  1538015148
# 3       3.36          1  1538013180
# 4      14.36         80  1538015149

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
df['Adj Temp'] = df['Max Temp'] - ((df['Elevation']*3.28084)*.0035)
df.to_csv('Output/Adjusted_Data.csv')
df.head()
# Out:
#                     City Country Latitude Longitude Elevation Max Temp  \
# 0              Srandakan      ID    -7.94    110.25      23.2    71.26
# 1         Saint-Philippe      RE   -21.36     55.77     29.17     69.8
# 2                 Forbes      AU   -33.38    148.01   241.703    58.39
# 3   Vila Franca Do Campo      PT    37.72    -25.43   32.0885     73.4
# 4                Fortuna      US     40.6   -124.16   25.8754     53.6
# 5        Arraial Do Cabo      BR   -22.97    -42.02   8.56655    75.49
# 6                Rikitea      PF   -23.12   -134.97   10.8869    71.26
# 7             Nikolskoye      RU     59.7     30.79   25.5733     48.2
# 8               Chervone      UA    47.83     37.79   146.675    33.19
# 9                 Dikson      RU    73.51     80.55    40.834    39.76
# 10            Chokurdakh      RU    70.62     147.9   30.1899     35.8
# 11                Narsaq      GL    60.91    -46.05   1.74374     35.6
# 12             Fairbanks      US    64.84   -147.72   135.486    51.08
# 13          San Patricio      MX    19.22    -104.7  0.967775    76.57
# 14                  Muli      MV     2.92     73.57         0    78.91
# 15                Harper      LR     4.38     -7.71   9.74245    78.19
# 16                 Pisco      PE   -13.71     -76.2        22     64.4
# 17               Chapais      CA    49.78    -74.86   394.944     39.2
# 18              Victoria      SC    -4.62     55.45   10.1672       77
# 19                Affery      CI     6.32     -3.95   111.723    73.42
# 20                Albany      AU   -35.02    117.88   45.3894    53.17
# 21             Sinnamary      GF     5.38    -52.96   4.19289    82.42
# 22            Georgetown      SH    -7.93    -14.42   1.62266    75.58
# 23              Lorengau      PG    -2.02    147.27  0.950974     84.4
# 24                 Luwuk      ID    -0.95    122.79   10.8231    79.45
#
#    Humidity Wind Speed Cloudiness        Date Adj Temp
# 0        92       3.76         64  1538009571  70.9936
# 1        59       2.24          0  1538006400   69.465
# 2        84       9.46          0  1538009575  55.6145
# 3        83      13.87         20  1538008200  73.0315
# 4        87       8.05         20  1538008740  53.3029
# 5        82      26.35          0  1538009575  75.3916
# 6       100      23.33         64  1538009576   71.135
# 7        70      11.18         75  1538006400  47.9063
# 8        81       3.65          0  1538009576  31.5057
# 9        96      21.54         92  1538009577  39.2911
# 10       92      14.27         92  1538009577  35.4533
# 11       64        4.7         75  1538005800    35.58
# 12       61      10.29         90  1538006280  49.5242
# 13      100       1.63         48  1538009578  76.5589
# 14      100      17.63         88  1538009578    78.91
# 15      100      11.81         92  1538009578  78.0781
# 16       77      13.87         90  1538006400  64.1474
# 17       86       9.17         90  1538008260  34.6649
# 18       88      14.99         36  1538006400  76.8833
# 19       99       2.75         92  1538009579  72.1371
# 20       91       6.78         92  1538009580  52.6488
# 21       95      17.29          8  1538009580  82.3719
# 22      100      18.07         48  1538009581  75.5614
# 23       99        5.1          8  1538009581  84.3891
# 24       88       6.67         12  1538009351  79.3257

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.figure(figsize=(20,12))
plt.scatter(df['Latitude'], df['Max Temp'], alpha=.25)
plt.grid(alpha=.25)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('City Latitude vs Max Temperature (9/26/18)')
plt.savefig("Images/LatvsTemp.png",bbox_inches="tight")

# %%
plt.figure(figsize=(20,12))
plt.scatter(df['Latitude'], df['Adj Temp'], alpha=.25)
plt.grid(alpha=.25)
plt.xlabel('Latitude')
plt.ylabel('Adj Temperature (F)')
plt.title('City Latitude vs Adj Temperature (9/26/18)')
plt.savefig("Images/LatvsAdjTemp.png",bbox_inches="tight")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(20,12))
plt.scatter(df['Latitude'],df['Humidity'], alpha=.25)
plt.grid(alpha=.25)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs Humidity (9/26/18)')
plt.savefig("Images/LatvsHum.png",bbox_inches="tight")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(20,12))
plt.scatter(df['Latitude'],df['Cloudiness'], alpha=.25)
plt.grid(alpha=.25)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs Cloudiness (9/26/18)')
plt.savefig("Images/LatvsCloud.png",bbox_inches="tight")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(20,12))
plt.scatter(df['Latitude'],df['Wind Speed'], alpha=.25)
plt.grid(alpha=.25)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('City Latitude vs Wind Speed (9/26/18)')
plt.savefig("Images/LatvsWind.png",bbox_inches="tight")
